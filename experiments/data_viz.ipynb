# %% [markdown]
# # Data Viz

# %%
import numpy as np
import math
from PIL import Image

# %%
# %run helper.py
# %run data_exploration.ipynb

# %%
hgain_events.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f5e63759bec4> in <module>()
# ----> 1 hgain_events.shape
#
# NameError: name 'hgain_events' is not defined

# %% [markdown]
# ## Example

# %%
x = np.random.rand(200,200)
x_scaled = np.uint8(255 * (x - x.min()) / (x.max() - x.min()))
Image.fromarray(x_scaled)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x10C6C8828>

# %%
x_scaled.shape
# Out:
# (200, 200)

# %% [markdown]
# ## Attempt

# %%
hgain_events.max()
# Out:
# 40.201351165771484

# %%
hgain_events.min()
# Out:
# 0.0

# %%
hgain_events.dtype
# Out:
# dtype('float64')

# %% [markdown]
# Note availble modes (RGB, etc):
# http://pillow.readthedocs.io/en/3.1.x/handbook/concepts.html#concept-modes

# %%
img = Image.fromarray(hgain_events, 'RGB')

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=163x31620 at 0x11A7FF668>
